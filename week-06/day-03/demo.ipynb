# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
Sales = pd.read_excel('Superstore.xls', index_col=0)

# %%
Sales.head()
# Out:
#         Order ID Order Date Order Priority  Order Quantity      Sales  \
# Row ID
# 1              3 2010-10-13            Low               6   261.5400
# 2              6 2012-02-20  Not Specified               2     6.9300
# 3             32 2011-07-15           High              26  2808.0800
# 4             32 2011-07-15           High              24  1761.4000
# 5             32 2011-07-15           High              23   160.2335
#
#         Discount       Ship Mode    Profit  Unit Price  Shipping Cost  ...  \
# Row ID                                                                 ...
# 1           0.04     Regular Air  -213.250       38.94          35.00  ...
# 2           0.01     Regular Air    -4.640        2.08           2.56  ...
# 3           0.07     Regular Air  1054.820      107.53           5.81  ...
# 4           0.09  Delivery Truck -1748.560       70.89          89.30  ...
# 5           0.04     Regular Air   -85.129        7.99           5.03  ...
#
# ...

# %%
Sales.describe()
# Out:
#            Order ID  Order Quantity         Sales     Discount        Profit  \
# count   8399.000000     8399.000000   8399.000000  8399.000000   8399.000000
# mean   29965.179783       25.571735   1775.878179     0.049671    181.184422
# std    17260.883447       14.481071   3585.050525     0.031823   1196.653326
# min        3.000000        1.000000      2.240000     0.000000 -14140.701600
# 25%    15011.500000       13.000000    143.195000     0.020000    -83.315000
# 50%    29857.000000       26.000000    449.420000     0.050000     -1.500000
# 75%    44596.000000       38.000000   1709.320000     0.080000    162.748000
# max    59973.000000       50.000000  89061.050000     0.250000  27220.690000
#
#         Unit Price  Shipping Cost      Zip Code  Product Base Margin
# count  8399.000000    8399.000000   8399.000000          8336.000000
# mean     89.346259      12.838557  52839.139421             0.512513
# std     290.354383      17.264052  28509.535635             0.135589
# ...

# %%
#Check the overall numbers
Sales["Sales"].groupby(Sales["Region"]).sum()

labels = Sales["Region"].unique()
sizes = Sales["Sales"].groupby(Sales["Region"]).sum()
#explode = (0, 0, 0.3, 0)  

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  

plt.show()

# %%
#this will render a warning but irrelevant in this case
Sales.sort_values(by=['Order Date'], inplace=True)
Sales
# Out:
#         Order ID Order Date Order Priority  Order Quantity       Sales  \
# Row ID
# 1914       13729 2009-01-01  Not Specified               9    872.4800
# 4031       28774 2009-01-01           High              32    180.3600
# 5272       37537 2009-01-02            Low               4   1239.0600
# 6224       44069 2009-01-02       Critical              16    137.6300
# 6225       44069 2009-01-02       Critical              43    614.8000
# 1279        9285 2009-01-02       Critical               3    124.8100
# 5273       37537 2009-01-02            Low              43   4083.1900
# 5274       37537 2009-01-02            Low              32   4902.3800
# 4223       30016 2009-01-03       Critical              15     85.5600
# 1316        9637 2009-01-03            Low              49  28359.4000
# 1074        7909 2009-01-03           High              29    122.2300
# 1315        9637 2009-01-03            Low              12    522.4900
# ...

# %%
x = np.array(Sales["Order Date"].unique())
y = np.array(Sales["Sales"].astype(int).groupby(Sales["Order Date"]).sum())
plt.plot(x,y, 'm')

#What is gonna happe n if I add this?
#plt.plot(x,y+30000)
plt.show()

# %%
Profits = Sales

# %%
# C) Which sub-category brought the highest profits?
ProfitsCategory = Profits.groupby(Profits["Product Sub-Category"]).sum()
ProfitsCategory.head()
# Out:
#                                 Order ID  Order Quantity       Sales  \
# Product Sub-Category
# Appliances                      12602508           10901   736991.54
# Binders and Binder Accessories  27932832           22992  1022957.59
# Bookcases                        5224640            4891   822652.04
# Chairs & Chairmats              11841788            9590  1761836.55
# Computer Peripherals            22156363           19222   795875.94
#
#                                 Discount       Profit  Unit Price  \
# Product Sub-Category
# Appliances                         21.98   97158.0600    31525.68
# Binders and Binder Accessories     46.10  307413.4180    52706.18
# Bookcases                           9.09  -33582.1335    32665.80
# Chairs & Chairmats                 19.42  149649.7250    70691.13
# Computer Peripherals               36.82   94287.4800    32218.23
#
#                                 Shipping Cost  Zip Code  Product Base Margin
# Product Sub-Category
# ...

# %%
categories = ProfitsCategory.groupby('Product Sub-Category')
categories.head()
# Out:
#                                 Order ID  Order Quantity        Sales  \
# Product Sub-Category
# Appliances                      12602508           10901   736991.540
# Binders and Binder Accessories  27932832           22992  1022957.590
# Bookcases                        5224640            4891   822652.040
# Chairs & Chairmats              11841788            9590  1761836.550
# Computer Peripherals            22156363           19222   795875.940
# Copiers and Fax                  2553341            2128  1130361.300
# Envelopes                        7544439            6578   174085.800
# Labels                           8394476            7301    38981.550
# Office Furnishings              23675240           20648   698093.810
# Office Machines                 10350533            7856  2168697.140
# Paper                           37392811           30871   446452.860
# Pens & Art Supplies             18875174           16980   167107.220
# ...

# %%
values = categories['Profit'].sum()#.sort_values(ascending=False)
values
# Out:
# Product Sub-Category
# Appliances                         97158.060000
# Binders and Binder Accessories    307413.418000
# Bookcases                         -33582.133500
# Chairs & Chairmats                149649.725000
# Computer Peripherals               94287.480000
# Copiers and Fax                   167361.464000
# Envelopes                          48182.600000
# Labels                             13677.170000
# Office Furnishings                100427.924000
# Office Machines                   307712.930300
# Paper                              45263.200000
# Pens & Art Supplies                 7564.780000
# Rubber Bands                        -102.670000
# Scissors, Rulers and Trimmers      -7799.250000
# Storage & Organization              6664.150000
# Tables                            -99062.529219
# Telephones and Communication      316951.641000
# Name: Profit, dtype: float64

# %%
values.plot(kind='bar', figsize=(15, 4), color='blue', alpha=0.8)

# %%
men_means, men_std = (20, 35, 30, 35, 27), (2, 3, 4, 1, 2)
women_means, women_std = (25, 32, 34, 20, 25), (3, 5, 2, 3, 3)

ind = np.arange(len(men_means))  # the x locations for the groups
width = 0.35  # the width of the bars
# Out:
# array([0, 1, 2, 3, 4])

# %%
fig, ax = plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x22628e2fc88>)

# %%
rects1 = ax.bar(ind - width/2, men_means, width, yerr=men_std,
                label='Men')
rects2 = ax.bar(ind + width/2, women_means, width, yerr=women_std,
                label='Women')
# Out:
# <BarContainer object of 5 artists>

# %%
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')

ax.set_xticks(ind)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
ax.legend()

# %%
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0, 'right': 1, 'left': -1}

    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(offset[xpos]*3, 3),  # use 3 points offset
                    textcoords="offset points",  # in both directions
                    ha=ha[xpos], va='bottom')


autolabel(rects1, "left")
autolabel(rects2, "right")

fig.tight_layout()

plt.show()
