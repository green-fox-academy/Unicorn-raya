# %%
# task2
#add more station on the place where clusting more data



import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import geopandas

# %%
ab_path = "C:\\Users\\Ray_Zhang\\greenfox\\Unicorn-raya\\week-06\\day-03\\la_bike_trip\\trip_data.csv"
trip_data =  pd.read_csv(ab_path)
trip_data.columns
trip_data.fillna(0,inplace=True)
useful_data = trip_data[(trip_data["Starting Station Longitude"] != 0)&(trip_data["Ending Station Latitude"] != 0)]
useful_data
# Out:
#          Trip ID  Duration               Start Time                 End Time  \
# 25      17848847       480  2017-01-13T21:32:00.000  2017-01-13T21:40:00.000
# 26      20700706       540  2017-02-24T23:13:00.000  2017-02-24T23:22:00.000
# 27      20595730       840  2017-02-23T07:34:00.000  2017-02-23T07:48:00.000
# 28      17307719       420  2017-01-05T12:04:00.000  2017-01-05T12:11:00.000
# 31      18941656       840  2017-01-30T20:19:00.000  2017-01-30T20:33:00.000
# 33      18023215       300  2017-01-16T18:14:00.000  2017-01-16T18:19:00.000
# 36      21926434       540  2017-03-12T12:37:00.000  2017-03-12T12:46:00.000
# 37      21684654      1260  2017-03-09T17:27:00.000  2017-03-09T17:48:00.000
# 39      23355994       720  2017-03-28T13:47:00.000  2017-03-28T13:59:00.000
# 41      21435123       420  2017-03-06T14:31:00.000  2017-03-06T14:38:00.000
# 42      22478874       600  2017-03-18T10:47:00.000  2017-03-18T10:57:00.000
# ...

# %%
gdf = geopandas.GeoDataFrame(useful_data,
                             geometry=geopandas.points_from_xy(useful_data['Starting Station Longitude'],useful_data["Starting Station Latitude"]))
